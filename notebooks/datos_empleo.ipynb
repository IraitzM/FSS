# %% [markdown]
# Vamos a buscar en los recursos online qué datos de empleo podemos obtener.
#
# ## Ayuntamiento de Donosti
#
# El ayuntamiento de Donosti tiene una web de datos abiertos: https://www.donostia.eus/datosabiertos/
#
# En la [sección de empleo podemos](https://www.donostia.eus/datosabiertos/tema/empleo) ver que existe un CSV (fichero separado por coma) que podría valernos.
#
# ![empleo](../images/empleo.png)

# %% [markdown]
# Veremos que nos da opciones de descargar o consultar vía API los datos de empleo, aunque no siempre funcione todo.

# %%
import pandas as pd

ciudad = pd.read_csv("https://www.donostia.eus/datosabiertos/recursos/eustat_paro/eustatparociudad.csv")
ciudad
# Out:
#    Urtea  Langabezia Tasa  Gizonen Langabezia Tasa  Emakumeen Langabezia Tasa  \
# 0   2016            12.00                    11.70                      12.30
# 1   2017             9.50                     9.00                      10.00
# 2   2018             8.50                     8.20                       8.90
# 3   2019             8.01                     7.60                       8.41
# 4   2020             9.47                     9.11                       9.82
#
#    16-39 adinekoen langabezia tasa  40-64 adinekoen langabezia tasa  \
# 0                            15.30                            10.40
# 1                            11.00                             8.90
# 2                             9.50                             8.10
# 3                             9.37                             7.45
# 4                            11.27                             8.75
#
#    65+ adinekoen langabezia tasa  Bertakoen langabezia tasa  \
# 0                           3.70                      11.00
# 1                           0.70                       8.90
# 2                           0.80                       8.00
# 3                           0.65                       7.53
# 4                           2.32                       8.83
#
#    Atzerritarren langabezia tasa
# 0                          22.40
# 1                          17.10
# 2                          14.20
# 3                          12.97
# 4                          16.40

# %%
unidad_menor = pd.read_csv("https://www.donostia.eus/datosabiertos/recursos/eustat_paro/eustatparoumenor.csv")
unidad_menor
# Out:
#      Urtea  AuzoKodea             Auzoa  UnitateTxikiKodea  \
# 0     2016          1             Aiete                101
# 1     2016          1             Aiete                102
# 2     2016          1             Aiete                103
# 3     2016          1             Aiete                104
# 4     2016          1             Aiete                105
# ..     ...        ...               ...                ...
# 395   2019         16  Miramon-Zorroaga               1604
# 396   2019         16  Miramon-Zorroaga               1605
# 397   2019         16  Miramon-Zorroaga               1606
# 398   2019         17           Zubieta               1701
# 399   2019         17           Zubieta               1702
#
#           UnitateTxikia  Langabezia Tasa  Gizonen Langabezia Tasa  \
# 0            Arbaizenea            13.80                    14.40
# 1           Bera - Bera            10.10                     8.10
# 2               Errondo            10.40                     6.50
# 3                Etxadi             9.60                     9.40
# 4              Lugaritz             6.00                     4.40
# ..                  ...              ...                      ...
# 395             Miramon             2.88                     3.80
# 396           Oriamendi             4.59                     2.09
# 397            Zorroaga             3.32                     1.38
# 398  Hipodromo - Bugati             0.00                     0.00
# 399             Zubieta             4.40                     6.38
#
#      Emakumeen Langabezia Tasa  16-39 adinekoen langabezia tasa  \
# 0                        13.20                            21.30
# 1                        12.20                            17.90
# 2                        16.00                            14.90
# 3                         9.80                            13.50
# 4                         7.70                             6.30
# ..                         ...                              ...
# 395                       1.67                             4.35
# 396                       7.26                             6.12
# 397                       5.56                             8.00
# 398                       0.00                             0.00
# 399                       2.27                            10.53
#
#      40-64 adinekoen langabezia tasa  65+ adinekoen langabezia tasa  \
# 0                              11.20                            0.0
# 1                               6.30                            3.2
# 2                               7.90                            0.0
# 3                               7.80                            0.0
# 4                               5.80                            0.0
# ..                               ...                            ...
# 395                             2.22                            0.0
# 396                             4.12                            0.0
# 397                             1.59                            0.0
# 398                             0.00                            0.0
# 399                             2.78                            0.0
#
#      Bertakoen langabezia tasa  Atzerritarren langabezia tasa
# 0                        12.40                          31.80
# 1                        10.30                           2.80
# 2                         8.40                          33.30
# 3                         9.40                          14.10
# 4                         5.80                           9.40
# ..                         ...                            ...
# 395                       3.10                           0.00
# 396                       4.87                           0.00
# 397                       3.08                           9.09
# 398                       0.00                            NaN
# 399                       4.44                           0.00
#
# [400 rows x 13 columns]

# %% [markdown]
# Por ejemplo, los datos de barrio, deberemos descargárnoslos.

# %%
barrio = pd.read_csv("../data/eustatparobarrio.csv")
barrio
# Out:
#     Urtea  AuzoKodea               Auzoa  Langabezia Tasa  \
# 0    2016          1               AIETE             9.70
# 1    2016          2               ALTZA            14.60
# 2    2016          3         AMARA BERRI            11.90
# 3    2016          4             ANTIGUO             9.40
# 4    2016          5              AÑORGA            10.80
# ..    ...        ...                 ...              ...
# 85   2020         14           MARTUTENE            10.49
# 86   2020         15  MIRACRUZ-BIDEBIETA            11.86
# 87   2020         16    MIRAMON-ZORROAGA             6.41
# 88   2020         17             ZUBIETA             8.41
# 89   2020         18          LANDARBASO              NaN
#
#     Gizonen Langabezia Tasa  Emakumeen Langabezia Tasa  \
# 0                      8.80                      10.70
# 1                     13.40                      15.80
# 2                     11.50                      12.20
# 3                      9.30                       9.60
# 4                      9.30                      12.40
# ..                      ...                        ...
# 85                    10.03                      10.94
# 86                    10.56                      13.14
# 87                     5.55                       7.33
# 88                     8.16                       8.62
# 89                      NaN                        NaN
#
#     16-39 adinekoen langabezia tasa  40-64 adinekoen langabezia tasa  \
# 0                             13.80                             7.70
# 1                             16.90                            13.10
# 2                             14.80                            10.20
# 3                             13.40                             7.70
# 4                             13.90                             9.10
# ..                              ...                              ...
# 85                            12.94                             9.57
# 86                            14.75                            10.68
# 87                            10.27                             4.74
# 88                            14.29                             6.33
# 89                              NaN                              NaN
#
#     65+ adinekoen langabezia tasa  Bertakoen langabezia tasa  \
# 0                            1.90                       9.50
# 1                            9.50                      13.00
# 2                            0.70                      10.60
# 3                            1.90                       8.90
# 4                            0.00                      10.10
# ..                            ...                        ...
# 85                           0.00                       9.83
# 86                           9.43                      11.19
# 87                           0.00                       6.22
# 88                            NaN                       6.93
# 89                            NaN                        NaN
#
#     Atzerritarren langabezia tasa
# 0                           14.30
# 1                           31.60
# 2                           21.80
# 3                           16.40
# 4                           24.50
# ..                            ...
# 85                          17.54
# 86                          18.40
# 87                          10.00
# 88                          33.33
# 89                            NaN
#
# [90 rows x 11 columns]

# %%
barrio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 11 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Urtea                            90 non-null     int64
#  1   AuzoKodea                        90 non-null     int64
#  2   Auzoa                            90 non-null     object
#  3   Langabezia Tasa                  88 non-null     float64
#  4   Gizonen Langabezia Tasa          88 non-null     float64
#  5   Emakumeen Langabezia Tasa        88 non-null     float64
#  6   16-39 adinekoen langabezia tasa  88 non-null     float64
#  7   40-64 adinekoen langabezia tasa  88 non-null     float64
#  8   65+ adinekoen langabezia tasa    82 non-null     float64
#  9   Bertakoen langabezia tasa        88 non-null     float64
#  10  Atzerritarren langabezia tasa    85 non-null     float64
# dtypes: float64(8), int64(2), object(1)
# memory usage: 7.9+ KB

# %% [markdown]
# Vemos en el conjunto de datos general que existen tres grupos diferenciados:
#
# * General
# * Hombres y mujeres
# * Grupos de edad
# * Locales y extranjeros

# %%
from visuals import plot_unemployment_rates

plot_unemployment_rates(ciudad);

# %%
import matplotlib.pyplot as plt
from visuals import plot_unemployment_comparison

columns_to_plot = ['Langabezia Tasa', 'Gizonen Langabezia Tasa', 'Emakumeen Langabezia Tasa']
labels = ['Total', 'Gizon', 'Emakume']

fig, ax = plot_unemployment_comparison(
    ciudad, 
    columns_to_plot=columns_to_plot,
    column_labels=labels,
    figsize=(12, 6)
)
plt.show()

# %%
columns_to_plot = ['Langabezia Tasa', '16-39 adinekoen langabezia tasa','40-64 adinekoen langabezia tasa','65+ adinekoen langabezia tasa']
labels = ['Total', '<39', '40-64','65+']

fig, ax = plot_unemployment_comparison(
    ciudad, 
    columns_to_plot=columns_to_plot,
    column_labels=labels,
    figsize=(12, 6)
)
plt.show()

# %%
columns_to_plot = ['Langabezia Tasa', 'Bertakoen langabezia tasa','Atzerritarren langabezia tasa']
labels = ['Total', 'Bertako','Atzerritar']

fig, ax = plot_unemployment_comparison(
    ciudad, 
    columns_to_plot=columns_to_plot,
    column_labels=labels,
    figsize=(12, 6)
)
plt.show()

# %% [markdown]
# # Limpieza de datos
#
# Podemos intentar buscar en otras fuentes información adicional que nos ayude a proyectar qué es lo que ha podido pasar en Donosti basado en datos de Gipuzkoa (por ejemplo).
#
# Datos de Open Data Euskadi: https://opendata.euskadi.eus/catalogo/-/estadistica/paro-registrado-desde-1997/

# %%
pd.read_csv("https://opendata.euskadi.eus/contenidos/estadistica/paro_historico/es_def/adjuntos/Dap_Historico.csv", encoding="latin-1", sep=";")
# Out:
#       Matriz de datos históricos de demandantes activos parados Unnamed: 1  \
# 0                                                    Año         Trimestre
# 1                                                  1.997                 1
# 2                                                  1.997                 1
# 3                                                  1.997                 1
# 4                                                  1.997                 1
# ...                                                  ...               ...
# 11955                                              2.008                 4
# 11956                                              2.008                 4
# 11957                                              2.008                 4
# 11958                                              2.008                 4
# 11959                                              2.009               NaN
#
#       Unnamed: 2 Unnamed: 3         Unnamed: 4           Unnamed: 5  \
# 0      Codigo TH       T.H.  Cod. Comarca a 30  Descr. Comarca a 30
# 1             01      ARABA                 15      LLANADA ALAVESA
# 2             01      ARABA                 13       VALLE DE AIALA
# 3             01      ARABA                 16       ESTRIB. GORBEA
# 4             01      ARABA                 13       VALLE DE AIALA
# ...          ...        ...                ...                  ...
# 11955         48    BIZKAIA                 27        MEDIO NERVION
# 11956         48    BIZKAIA                 29     MARGEN IZQUIERDA
# 11957         48    BIZKAIA                 23          BUSTURIALDE
# 11958         48    BIZKAIA                 24        LEA - ARTIBAI
# 11959        NaN        NaN                NaN                  NaN
#
#               Unnamed: 6           Unnamed: 7      Unnamed: 8  \
# 0      Cod. Comarca a 11  Descr. Comarca a 11  Cod. Municipio
# 1                     01      VITORIA-GASTEIZ           01001
# 2                     02       VALLE DE AIALA           01002
# 3                     02       VALLE DE AIALA           01003
# 4                     02       VALLE DE AIALA           01004
# ...                  ...                  ...             ...
# 11955                 05     MARGEN IZQUIERDA           48912
# 11956                 05     MARGEN IZQUIERDA           48913
# 11957                 06        BIZKAIA KOSTA           48914
# 11958                 06        BIZKAIA KOSTA           48915
# 11959                NaN                  NaN             NaN
#
#              Unnamed: 9  ...             Unnamed: 15  \
# 0      Nombre Municipio  ...  Industrias Extractivas
# 1      ALEGRIA-DULANTZI  ...                       0
# 2               AMURRIO  ...                       0
# 3               ARAMAIO  ...                       0
# 4            ARTZINIEGA  ...                       0
# ...                 ...  ...                     ...
# 11955        ALONSOTEGI  ...                       1
# 11956          ZIERBENA  ...                       0
# 11957           ARRATZU  ...                       0
# 11958   Ziortza-Bolibar  ...                       0
# 11959               NaN  ...                     NaN
#
#                      Unnamed: 16   Unnamed: 17            Unnamed: 18  \
# 0      Industrias Manufactureras  Construcción  Comercio y Hostelería
# 1                             17             1                      8
# 2                            140            73                     49
# 3                             17             1                      1
# 4                             16             3                      5
# ...                          ...           ...                    ...
# 11955                         18            36                     36
# 11956                          7             6                      2
# 11957                          3             2                      1
# 11958                          2             2                      2
# 11959                        NaN           NaN                    NaN
#
#                         Unnamed: 19         Unnamed: 20      Unnamed: 21  \
# 0      Transportes y Comunicaciones  Seguros y Finanzas  Otros Servicios
# 1                                 2                   0               27
# 2                                 4                   3              144
# 3                                 0                   1               14
# 4                                 0                   1               19
# ...                             ...                 ...              ...
# 11955                             5                   0               51
# 11956                             4                   0               22
# 11957                             0                   0                4
# 11958                             0                   0                3
# 11959                           NaN                 NaN              NaN
#
#                Unnamed: 22 Unnamed: 23 Unnamed: 24
# 0      Sin empleo anterior         NaN         NaN
# 1                        6         NaN         NaN
# 2                      144         NaN         NaN
# 3                        9         NaN         NaN
# 4                       16         NaN         NaN
# ...                    ...         ...         ...
# 11955                    8         NaN         NaN
# 11956                    2         NaN         NaN
# 11957                    1         NaN         NaN
# 11958                    0         NaN         NaN
# 11959                  NaN         NaN         NaN
#
# [11960 rows x 25 columns]

# %%
datos_euskadi = pd.read_csv("https://opendata.euskadi.eus/contenidos/estadistica/paro_historico/es_def/adjuntos/Dap_Historico.csv", encoding="latin-1", sep=";", skiprows=1, header=0)
datos_euskadi
# Out:
#          Año  Trimestre  Codigo TH     T.H.  Cod. Comarca a 30  \
# 0      1.997        1.0        1.0    ARABA               15.0
# 1      1.997        1.0        1.0    ARABA               13.0
# 2      1.997        1.0        1.0    ARABA               16.0
# 3      1.997        1.0        1.0    ARABA               13.0
# 4      1.997        1.0        1.0    ARABA               17.0
# ...      ...        ...        ...      ...                ...
# 11954  2.008        4.0       48.0  BIZKAIA               27.0
# 11955  2.008        4.0       48.0  BIZKAIA               29.0
# 11956  2.008        4.0       48.0  BIZKAIA               23.0
# 11957  2.008        4.0       48.0  BIZKAIA               24.0
# 11958  2.009        NaN        NaN      NaN                NaN
#
#       Descr. Comarca a 30  Cod. Comarca a 11 Descr. Comarca a 11  \
# 0         LLANADA ALAVESA                1.0     VITORIA-GASTEIZ
# 1          VALLE DE AIALA                2.0      VALLE DE AIALA
# 2          ESTRIB. GORBEA                2.0      VALLE DE AIALA
# 3          VALLE DE AIALA                2.0      VALLE DE AIALA
# 4         VALLES ALAVESES                1.0     VITORIA-GASTEIZ
# ...                   ...                ...                 ...
# 11954       MEDIO NERVION                5.0    MARGEN IZQUIERDA
# 11955    MARGEN IZQUIERDA                5.0    MARGEN IZQUIERDA
# 11956         BUSTURIALDE                6.0       BIZKAIA KOSTA
# 11957       LEA - ARTIBAI                6.0       BIZKAIA KOSTA
# 11958                 NaN                NaN                 NaN
#
#        Cod. Municipio  Nombre Municipio  ...  Energía, Gas y Agua  \
# 0              1001.0  ALEGRIA-DULANTZI  ...                  1.0
# 1              1002.0           AMURRIO  ...                  2.0
# 2              1003.0           ARAMAIO  ...                  0.0
# 3              1004.0        ARTZINIEGA  ...                  0.0
# 4              1006.0           ARMIÑON  ...                  0.0
# ...               ...               ...  ...                  ...
# 11954         48912.0        ALONSOTEGI  ...                  0.0
# 11955         48913.0          ZIERBENA  ...                  0.0
# 11956         48914.0           ARRATZU  ...                  0.0
# 11957         48915.0   Ziortza-Bolibar  ...                  0.0
# 11958             NaN               NaN  ...                  NaN
#
#        Industrias Extractivas  Industrias Manufactureras  Construcción  \
# 0                         0.0                       17.0           1.0
# 1                         0.0                      140.0          73.0
# 2                         0.0                       17.0           1.0
# 3                         0.0                       16.0           3.0
# 4                         0.0                        2.0           0.0
# ...                       ...                        ...           ...
# 11954                     1.0                       18.0          36.0
# 11955                     0.0                        7.0           6.0
# 11956                     0.0                        3.0           2.0
# 11957                     0.0                        2.0           2.0
# 11958                     NaN                        NaN           NaN
#
#        Comercio y Hostelería  Transportes y Comunicaciones  \
# 0                        8.0                           2.0
# 1                       49.0                           4.0
# 2                        1.0                           0.0
# 3                        5.0                           0.0
# 4                        3.0                           0.0
# ...                      ...                           ...
# 11954                   36.0                           5.0
# 11955                    2.0                           4.0
# 11956                    1.0                           0.0
# 11957                    2.0                           0.0
# 11958                    NaN                           NaN
#
#        Seguros y Finanzas  Otros Servicios  Sin empleo anterior  Unnamed: 23
# 0                     0.0             27.0                  6.0          NaN
# 1                     3.0            144.0                144.0          NaN
# 2                     1.0             14.0                  9.0          NaN
# 3                     1.0             19.0                 16.0          NaN
# 4                     0.0              2.0                  1.0          NaN
# ...                   ...              ...                  ...          ...
# 11954                 0.0             51.0                  8.0          NaN
# 11955                 0.0             22.0                  2.0          NaN
# 11956                 0.0              4.0                  1.0          NaN
# 11957                 0.0              3.0                  0.0          NaN
# 11958                 NaN              NaN                  NaN          NaN
#
# [11959 rows x 24 columns]

# %%
datos_euskadi.describe()
# Out:
#                 Año     Trimestre     Codigo TH  Cod. Comarca a 30  \
# count  11959.000000  11958.000000  11958.000000       11958.000000
# mean       2.002516      2.498829     28.566734          15.958772
# std        0.003454      1.118005     18.676131           8.139572
# min        1.997000      1.000000      1.000000           1.000000
# 25%        2.000000      1.000000     20.000000           7.000000
# 50%        2.003000      2.000000     20.000000          17.000000
# 75%        2.006000      3.000000     48.000000          23.000000
# max        2.009000      4.000000     48.000000          30.000000
#
#        Cod. Comarca a 11  Cod. Municipio     Poblacion  Pobl. Activa  \
# count       11958.000000    11958.000000  11958.000000  11958.000000
# mean            5.897140    28084.756351    211.243306    216.305357
# std             2.939317    18965.476724    282.102473    249.163337
# min             1.000000        1.001000      0.000000      0.000000
# 25%             5.000000    20008.000000      3.963000      6.186000
# 50%             6.000000    20072.000000     24.265500    126.000000
# 75%             9.000000    48048.000000    357.000000    361.000000
# max            11.000000    48915.000000    997.000000    998.000000
#
#        TOTAL PARADOS  Agric., Ganad. y Pesca  Energía, Gas y Agua  \
# count   11958.000000            11958.000000         11958.000000
# mean      103.703350                2.901321             0.569911
# std       176.303154               10.279109             3.115156
# min         0.000000                0.000000             0.000000
# 25%         7.000000                0.000000             0.000000
# 50%        24.000000                0.000000             0.000000
# 75%       114.000000                2.000000             0.000000
# max       999.000000              169.000000           101.000000
#
#        Industrias Extractivas  Industrias Manufactureras  Construcción  \
# count            11958.000000               11958.000000  11958.000000
# mean                 0.434521                  45.624613     20.113352
# std                  3.108022                 105.050113     65.628795
# min                  0.000000                   0.000000      0.000000
# 25%                  0.000000                   2.000000      0.000000
# 50%                  0.000000                   7.000000      2.000000
# 75%                  0.000000                  41.000000     10.000000
# max                138.000000                 998.000000    887.000000
#
#        Comercio y Hostelería  Transportes y Comunicaciones  \
# count           11958.000000                  11958.000000
# mean               36.303683                      9.819786
# std                94.748598                     43.421876
# min                 0.000000                      0.000000
# 25%                 1.000000                      0.000000
# 50%                 5.000000                      1.000000
# 75%                26.000000                      4.000000
# max               971.000000                    684.000000
#
#        Seguros y Finanzas  Otros Servicios  Sin empleo anterior  Unnamed: 23
# count        11958.000000     11958.000000         11958.000000          0.0
# mean             2.596672        56.108306            30.949485          NaN
# std             13.415092       127.851761            91.870585          NaN
# min              0.000000         0.000000             0.000000          NaN
# 25%              0.000000         3.000000             0.000000          NaN
# 50%              0.000000        10.000000             3.000000          NaN
# 75%              1.000000        46.000000            17.000000          NaN
# max            223.000000       999.000000           995.000000          NaN

# %%
datos_euskadi[datos_euskadi["T.H."] == "GIPUZKOA"]
# Out:
#          Año  Trimestre  Codigo TH      T.H.  Cod. Comarca a 30  \
# 51     1.997        1.0       20.0  GIPUZKOA                5.0
# 52     1.997        1.0       20.0  GIPUZKOA                5.0
# 53     1.997        1.0       20.0  GIPUZKOA                6.0
# 54     1.997        1.0       20.0  GIPUZKOA                5.0
# 55     1.997        1.0       20.0  GIPUZKOA                5.0
# ...      ...        ...        ...       ...                ...
# 11841  2.008        4.0       20.0  GIPUZKOA                4.0
# 11842  2.008        4.0       20.0  GIPUZKOA                5.0
# 11843  2.008        4.0       20.0  GIPUZKOA                5.0
# 11844  2.008        4.0       20.0  GIPUZKOA                7.0
# 11845  2.008        4.0       20.0  GIPUZKOA                5.0
#
#       Descr. Comarca a 30  Cod. Comarca a 11 Descr. Comarca a 11  \
# 51             TOLOSALDEA                9.0     TOLOSA-GOIHERRI
# 52             TOLOSALDEA                9.0     TOLOSA-GOIHERRI
# 53            UROLA ERDIA                8.0        DONOSTIALDEA
# 54             TOLOSALDEA                9.0     TOLOSA-GOIHERRI
# 55             TOLOSALDEA                9.0     TOLOSA-GOIHERRI
# ...                   ...                ...                 ...
# 11841  DONOSTIALDEA OESTE                8.0        DONOSTIALDEA
# 11842          TOLOSALDEA                9.0     TOLOSA-GOIHERRI
# 11843          TOLOSALDEA                9.0     TOLOSA-GOIHERRI
# 11844            GOIHERRI                9.0     TOLOSA-GOIHERRI
# 11845          TOLOSALDEA                9.0     TOLOSA-GOIHERRI
#
#        Cod. Municipio Nombre Municipio  ...  Energía, Gas y Agua  \
# 51            20001.0     ABALTZISKETA  ...                  0.0
# 52            20002.0            ADUNA  ...                  0.0
# 53            20003.0     AIZARNAZABAL  ...                  0.0
# 54            20004.0         ALBIZTUR  ...                  0.0
# 55            20005.0           ALEGIA  ...                  0.0
# ...               ...              ...  ...                  ...
# 11841         20903.0      ASTIGARRAGA  ...                  1.0
# 11842         20904.0       BALIARRAIN  ...                  0.0
# 11843         20905.0         ORENDAIN  ...                  0.0
# 11844         20906.0          ALTZAGA  ...                  0.0
# 11845         20907.0          GAZTELU  ...                  0.0
#
#        Industrias Extractivas  Industrias Manufactureras  Construcción  \
# 51                        0.0                        0.0           3.0
# 52                        0.0                        3.0           0.0
# 53                        0.0                        2.0           0.0
# 54                        0.0                        1.0           3.0
# 55                        0.0                       22.0          11.0
# ...                       ...                        ...           ...
# 11841                     1.0                       20.0          14.0
# 11842                     0.0                        1.0           0.0
# 11843                     0.0                        0.0           0.0
# 11844                     0.0                        3.0           1.0
# 11845                     0.0                        0.0           1.0
#
#        Comercio y Hostelería  Transportes y Comunicaciones  \
# 51                       0.0                           0.0
# 52                       2.0                           1.0
# 53                       2.0                           2.0
# 54                       1.0                           0.0
# 55                      14.0                           3.0
# ...                      ...                           ...
# 11841                   45.0                           7.0
# 11842                    2.0                           0.0
# 11843                    1.0                           1.0
# 11844                    0.0                           0.0
# 11845                    1.0                           0.0
#
#        Seguros y Finanzas  Otros Servicios  Sin empleo anterior  Unnamed: 23
# 51                    0.0              1.0                  1.0          NaN
# 52                    0.0              5.0                  3.0          NaN
# 53                    0.0              5.0                  2.0          NaN
# 54                    0.0              3.0                  0.0          NaN
# 55                    0.0             21.0                 19.0          NaN
# ...                   ...              ...                  ...          ...
# 11841                 0.0             65.0                 10.0          NaN
# 11842                 0.0              1.0                  0.0          NaN
# 11843                 0.0              2.0                  0.0          NaN
# 11844                 0.0              2.0                  0.0          NaN
# 11845                 0.0              0.0                  0.0          NaN
#
# [4202 rows x 24 columns]

# %%
datos_euskadi[datos_euskadi["Cod. Comarca a 11"] == 8.0]
# Out:
#          Año  Trimestre  Codigo TH      T.H.  Cod. Comarca a 30  \
# 53     1.997        1.0       20.0  GIPUZKOA                6.0
# 59     1.997        1.0       20.0  GIPUZKOA                4.0
# 66     1.997        1.0       20.0  GIPUZKOA               11.0
# 67     1.997        1.0       20.0  GIPUZKOA                6.0
# 68     1.997        1.0       20.0  GIPUZKOA                6.0
# ...      ...        ...        ...       ...                ...
# 11830  2.008        4.0       20.0  GIPUZKOA                4.0
# 11836  2.008        4.0       20.0  GIPUZKOA               11.0
# 11838  2.008        4.0       20.0  GIPUZKOA               11.0
# 11840  2.008        4.0       20.0  GIPUZKOA                4.0
# 11841  2.008        4.0       20.0  GIPUZKOA                4.0
#
#       Descr. Comarca a 30  Cod. Comarca a 11 Descr. Comarca a 11  \
# 53            UROLA ERDIA                8.0        DONOSTIALDEA
# 59     DONOSTIALDEA OESTE                8.0        DONOSTIALDEA
# 66            UROLA KOSTA                8.0        DONOSTIALDEA
# 67            UROLA ERDIA                8.0        DONOSTIALDEA
# 68            UROLA ERDIA                8.0        DONOSTIALDEA
# ...                   ...                ...                 ...
# 11830  DONOSTIALDEA OESTE                8.0        DONOSTIALDEA
# 11836         UROLA KOSTA                8.0        DONOSTIALDEA
# 11838         UROLA KOSTA                8.0        DONOSTIALDEA
# 11840  DONOSTIALDEA OESTE                8.0        DONOSTIALDEA
# 11841  DONOSTIALDEA OESTE                8.0        DONOSTIALDEA
#
#        Cod. Municipio Nombre Municipio  ...  Energía, Gas y Agua  \
# 53            20003.0     AIZARNAZABAL  ...                  0.0
# 59            20009.0          ANDOAIN  ...                  0.0
# 66            20016.0              AIA  ...                  0.0
# 67            20017.0         AZKOITIA  ...                  0.0
# 68            20018.0         AZPEITIA  ...                  0.0
# ...               ...              ...  ...                  ...
# 11830         20073.0          USURBIL  ...                  0.0
# 11836         20079.0          ZARAUTZ  ...                  1.0
# 11838         20081.0           ZUMAIA  ...                  0.0
# 11840         20902.0     LASARTE-ORIA  ...                  0.0
# 11841         20903.0      ASTIGARRAGA  ...                  1.0
#
#        Industrias Extractivas  Industrias Manufactureras  Construcción  \
# 53                        0.0                        2.0           0.0
# 59                        0.0                      205.0          81.0
# 66                        0.0                        6.0           4.0
# 67                        1.0                       93.0          16.0
# 68                        0.0                      140.0          22.0
# ...                       ...                        ...           ...
# 11830                     0.0                       55.0          24.0
# 11836                     0.0                      219.0          61.0
# 11838                     0.0                      144.0          14.0
# 11840                     0.0                      225.0          87.0
# 11841                     1.0                       20.0          14.0
#
#        Comercio y Hostelería  Transportes y Comunicaciones  \
# 53                       2.0                           2.0
# 59                     117.0                          11.0
# 66                       9.0                           2.0
# 67                      46.0                           8.0
# 68                      50.0                          10.0
# ...                      ...                           ...
# 11830                   47.0                           9.0
# 11836                  232.0                          26.0
# 11838                   73.0                          14.0
# 11840                  184.0                          24.0
# 11841                   45.0                           7.0
#
#        Seguros y Finanzas  Otros Servicios  Sin empleo anterior  Unnamed: 23
# 53                    0.0              5.0                  2.0          NaN
# 59                    3.0            222.0                241.0          NaN
# 66                    0.0              6.0                  4.0          NaN
# 67                    2.0             85.0                107.0          NaN
# 68                    2.0            124.0                 86.0          NaN
# ...                   ...              ...                  ...          ...
# 11830                 0.0             83.0                  6.0          NaN
# 11836                 4.0            245.0                 30.0          NaN
# 11838                 2.0             96.0                  1.0          NaN
# 11840                 5.0            340.0                 55.0          NaN
# 11841                 0.0             65.0                 10.0          NaN
#
# [1152 rows x 24 columns]

# %%
datos_euskadi[datos_euskadi["Nombre Municipio"] == "DONOSTIA-SAN SEBASTIAN"].head(5)
# Out:
#         Año  Trimestre  Codigo TH      T.H.  Cod. Comarca a 30  \
# 119   1.997        1.0       20.0  GIPUZKOA                3.0
# 366   1.997        2.0       20.0  GIPUZKOA                3.0
# 613   1.997        3.0       20.0  GIPUZKOA                3.0
# 860   1.997        4.0       20.0  GIPUZKOA                3.0
# 1107  1.998        1.0       20.0  GIPUZKOA                3.0
#
#      Descr. Comarca a 30  Cod. Comarca a 11 Descr. Comarca a 11  \
# 119             DONOSTIA                8.0        DONOSTIALDEA
# 366             DONOSTIA                8.0        DONOSTIALDEA
# 613             DONOSTIA                8.0        DONOSTIALDEA
# 860             DONOSTIA                8.0        DONOSTIALDEA
# 1107            DONOSTIA                8.0        DONOSTIALDEA
#
#       Cod. Municipio        Nombre Municipio  ...  Energía, Gas y Agua  \
# 119          20069.0  DONOSTIA-SAN SEBASTIAN  ...                 15.0
# 366          20069.0  DONOSTIA-SAN SEBASTIAN  ...                 12.0
# 613          20069.0  DONOSTIA-SAN SEBASTIAN  ...                 11.0
# 860          20069.0  DONOSTIA-SAN SEBASTIAN  ...                 10.0
# 1107         20069.0  DONOSTIA-SAN SEBASTIAN  ...                  9.0
#
#       Industrias Extractivas  Industrias Manufactureras  Construcción  \
# 119                      5.0                      1.727         590.0
# 366                      3.0                      1.637         494.0
# 613                      3.0                      1.555         476.0
# 860                      2.0                      1.496         520.0
# 1107                     2.0                      1.390         489.0
#
#       Comercio y Hostelería  Transportes y Comunicaciones  Seguros y Finanzas  \
# 119                   2.256                         296.0               145.0
# 366                   2.193                         282.0               147.0
# 613                   2.101                         254.0               149.0
# 860                   2.190                         256.0               147.0
# 1107                  2.288                         242.0               135.0
#
#       Otros Servicios  Sin empleo anterior  Unnamed: 23
# 119             2.858                2.131          NaN
# 366             2.732                1.909          NaN
# 613             2.812                1.726          NaN
# 860             2.852                1.803          NaN
# 1107            2.840                1.686          NaN
#
# [5 rows x 24 columns]

# %%
datos_euskadi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11959 entries, 0 to 11958
# Data columns (total 24 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Año                           11959 non-null  float64
#  1   Trimestre                     11958 non-null  float64
#  2   Codigo TH                     11958 non-null  float64
#  3   T.H.                          11958 non-null  object
#  4   Cod. Comarca a 30             11958 non-null  float64
#  5   Descr. Comarca a 30           11958 non-null  object
#  6   Cod. Comarca a 11             11958 non-null  float64
#  7   Descr. Comarca a 11           11958 non-null  object
#  8   Cod. Municipio                11958 non-null  float64
#  9   Nombre Municipio              11958 non-null  object
#  10  Poblacion                     11958 non-null  float64
#  11  Pobl. Activa                  11958 non-null  float64
#  12  TOTAL PARADOS                 11958 non-null  float64
#  13  Agric., Ganad. y Pesca        11958 non-null  float64
#  14  Energía, Gas y Agua           11958 non-null  float64
#  15  Industrias Extractivas        11958 non-null  float64
#  16  Industrias Manufactureras     11958 non-null  float64
#  17  Construcción                  11958 non-null  float64
#  18  Comercio y Hostelería         11958 non-null  float64
#  19  Transportes y Comunicaciones  11958 non-null  float64
#  20  Seguros y Finanzas            11958 non-null  float64
#  21  Otros Servicios               11958 non-null  float64
#  22  Sin empleo anterior           11958 non-null  float64
#  23  Unnamed: 23                   0 non-null      float64
# dtypes: float64(20), object(4)
# memory usage: 2.2+ MB

# %%
datos_euskadi[datos_euskadi["Nombre Municipio"] == "DONOSTIA-SAN SEBASTIAN"][["Año","Trimestre", "Pobl. Activa","TOTAL PARADOS"]]
# Out:
#          Año  Trimestre  Pobl. Activa  TOTAL PARADOS
# 119    1.997        1.0        79.052         10.111
# 366    1.997        2.0        79.052          9.499
# 613    1.997        3.0        79.052          9.183
# 860    1.997        4.0        79.052          9.371
# 1107   1.998        1.0        79.052          9.170
# 1354   1.998        2.0        79.052          8.445
# 1601   1.998        3.0        79.052          8.068
# 1848   1.998        4.0        79.052          8.247
# 2095   1.999        1.0        79.052          8.021
# 2345   1.999        2.0        79.052          7.082
# 2595   1.999        3.0        79.052          6.869
# 2845   1.999        4.0        79.052          6.987
# 3095   2.000        1.0        79.052          6.998
# 3345   2.000        2.0        79.052          6.099
# 3595   2.000        3.0        79.052          6.053
# 3845   2.000        4.0        79.052          6.292
# 4095   2.001        1.0        79.052          6.323
# 4345   2.001        2.0        79.052          5.585
# 4595   2.001        3.0        79.052          5.601
# 4842   2.001        4.0        79.052          5.788
# 5087   2.002        1.0        79.052          6.180
# 5333   2.002        2.0        79.052          5.444
# 5576   2.002        3.0        79.052          5.573
# 5820   2.002        4.0        79.052          5.752
# 6067   2.003        1.0        86.062          6.041
# 6317   2.003        2.0        86.062          5.365
# 6567   2.003        3.0        86.062          5.546
# 6817   2.003        4.0        86.062          5.810
# 7067   2.004        1.0        86.062          5.816
# 7317   2.004        2.0        86.062          5.136
# 7567   2.004        3.0        86.062          5.060
# 7817   2.004        4.0        86.062          5.168
# 8067   2.005        1.0        86.062          5.348
# 8317   2.005        2.0        86.062          5.736
# 8567   2.005        3.0        86.062          5.979
# 8817   2.005        4.0        86.062          6.064
# 9067   2.006        1.0        86.062          6.348
# 9317   2.006        2.0        86.062          5.684
# 9567   2.006        3.0        86.062          5.699
# 9818   2.006        4.0        86.062          6.005
# 10069  2.007        1.0        86.062          6.220
# 10320  2.007        2.0        86.062          5.548
# 10571  2.007        3.0        86.964          5.676
# 10822  2.007        4.0        86.964          5.884
# 11073  2.008        1.0        86.964          6.412
# 11324  2.008        2.0        86.510          6.143
# 11575  2.008        3.0        86.510          6.355
# 11826  2.008        4.0        86.510          7.218

# %%
datos_promedio = datos_euskadi[datos_euskadi["Nombre Municipio"] == "DONOSTIA-SAN SEBASTIAN"][["Año", "Pobl. Activa","TOTAL PARADOS"]].groupby("Año").agg("mean")
datos_promedio.reset_index(inplace=True)
datos_promedio
# Out:
#       Año  Pobl. Activa  TOTAL PARADOS
# 0   1.997       79.0520        9.54100
# 1   1.998       79.0520        8.48250
# 2   1.999       79.0520        7.23975
# 3   2.000       79.0520        6.36050
# 4   2.001       79.0520        5.82425
# 5   2.002       79.0520        5.73725
# 6   2.003       86.0620        5.69050
# 7   2.004       86.0620        5.29500
# 8   2.005       86.0620        5.78175
# 9   2.006       86.0620        5.93400
# 10  2.007       86.5130        5.83200
# 11  2.008       86.6235        6.53200

# %%
datos_promedio.dtypes
# Out:
# Año              float64
# Pobl. Activa     float64
# TOTAL PARADOS    float64
# dtype: object

# %%
datos_promedio["Urtea"] = (datos_promedio["Año"]*1000).astype(int)

# %%
datos_promedio["Langabezia Tasa"] = (datos_promedio["TOTAL PARADOS"]/datos_promedio["Pobl. Activa"])*100
datos_promedio
# Out:
#       Año  Pobl. Activa  TOTAL PARADOS  Urtea  Langabezia Tasa
# 0   1.997       79.0520        9.54100   1997        12.069271
# 1   1.998       79.0520        8.48250   1998        10.730279
# 2   1.999       79.0520        7.23975   1999         9.158212
# 3   2.000       79.0520        6.36050   2000         8.045970
# 4   2.001       79.0520        5.82425   2001         7.367619
# 5   2.002       79.0520        5.73725   2001         7.257565
# 6   2.003       86.0620        5.69050   2003         6.612094
# 7   2.004       86.0620        5.29500   2004         6.152541
# 8   2.005       86.0620        5.78175   2005         6.718122
# 9   2.006       86.0620        5.93400   2005         6.895029
# 10  2.007       86.5130        5.83200   2007         6.741183
# 11  2.008       86.6235        6.53200   2008         7.540679

# %%
datos_completos = pd.concat([ciudad[["Urtea","Langabezia Tasa"]], datos_promedio[["Urtea","Langabezia Tasa"]]])
datos_completos
# Out:
#     Urtea  Langabezia Tasa
# 0    2016        12.000000
# 1    2017         9.500000
# 2    2018         8.500000
# 3    2019         8.010000
# 4    2020         9.470000
# 0    1997        12.069271
# 1    1998        10.730279
# 2    1999         9.158212
# 3    2000         8.045970
# 4    2001         7.367619
# 5    2001         7.257565
# 6    2003         6.612094
# 7    2004         6.152541
# 8    2005         6.718122
# 9    2005         6.895029
# 10   2007         6.741183
# 11   2008         7.540679

# %%
datos_completos = datos_completos.groupby("Urtea").agg("mean")
datos_completos.reset_index(inplace=True)

# %%
plot_unemployment_rates(datos_completos);

# %% [markdown]
# ### Web scrapping
#
# Quizás debamos buscar en fuentes menos oficiales: https://datosmacro.expansion.com/paro/espana/municipios/pais-vasco/guipuzcoa/donostia-san-sebastian

# %%
# !pip install requests

# %%
import requests

URL = "https://datosmacro.expansion.com/paro/espana/municipios/pais-vasco/guipuzcoa/donostia-san-sebastian"
page = requests.get(URL)

# %%
page.content
# Out:
# b'<!DOCTYPE html><html lang="es" dir="ltr" prefix="og: https://ogp.me/ns#"><head><meta charset="utf-8" />\n<meta name="description" content="Selecciona para ver el paro de los municipios de Espa\xc3\xb1a. Ranking de paro de Espa\xc3\xb1a por CCAA y provincias y evoluci\xc3\xb3n del desempleo en cada municipio. Mapa del paro en Espa\xc3\xb1a" />\n<link rel="canonical" href="https://datosmacro.expansion.com/paro/espana/municipios/pais-vasco/guipuzcoa/donostia-san-sebastian" />\n<meta property="og:site_name" content="Datosmacro.com" />\n<meta property="og:type" content="article" />\n<meta property="og:url" content="https://datosmacro.expansion.com/paro/espana/municipios/pais-vasco/guipuzcoa/donostia-san-sebastian" />\n<meta property="og:title" content="Paro por municipios: Donostia/San Sebasti\xc3\xa1n - (Gipuzkoa) 2025" />\n<meta property="og:description" content="Selecciona para ver el paro de los municipios de Espa\xc3\xb1a. Ranking de paro de Espa\xc3\xb1a por CCAA y provincias y evoluci\xc3\xb3n del desempleo en cada municipio. Mapa del paro en Espa\xc3\xb1a" />\n<meta property="fb:app_id" content="1436132716631029" />\n<meta name="twitter:card" content="summary" />\n<meta name="twitter:description" content="Selecciona para ver el paro de los municipios de Espa\xc3\xb1a. Ranking de paro de Espa\xc3\xb1a por CCAA y provincias y evoluci\xc3\xb3n del desempleo en cada municipio. Mapa del paro en Espa\xc3\xb1a" />\n<meta name="twitter:site" content="@Datosmacro.com" />\n<meta name="twitter:title" content="Paro por municipios: Donostia/San Sebasti\xc3\xa1n - (Gipuzkoa) 2025" />\n<meta name="MobileOptimized" content="width" />\n<meta name="HandheldFriendly" content="true" />\n<meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no" />\n<meta property="og:image" content="https://datosmacro.expansion.com/img/flag/ESg.png" />\n<meta name="twitter:image" content="https://datosmacro.expansion.com/img/flag/ESg.png" />\n<meta name="msapplication-TileColor" content="#4e80c0" />\n<meta name="msapplication-TileImage" content="/icons/ms-icon-144x144.png" />\n<meta http-equiv="x-ua-compatible" content="ie=edge" />\n<link rel="alternate" hreflang="es" href="https://datosmacro.expansion.com/paro/espana/municipios" />\n<link rel="apple-touch-icon" sizes="120x120" href="/icons/apple-touch-icon-120x120.png" />\n<link rel="apple-touch-icon" sizes="180x180" href="/icons/apple-touch-icon-180x180.png" />\n<link rel="apple-touch-icon" sizes="152x152" href="/icons/apple-touch-icon-152x152.png" />\n<link rel="apple-touch-icon" sizes="167x167" href="/icons/apple-touch-icon-167x167.png" />\n<link rel="icon" type="image/png" sizes="196x196" href="/icons/favicon-196x196.png" />\n<link rel="icon" type="image/png" sizes="160x160" href="/icons/favicon-160x160.png" />\n<link rel="icon" type="image/png" sizes="96x96" href="/icons/favicon-96x96.png" />\n<link rel="icon" type="image/png" sizes="32x32" href="/icons/favicon-32x32.png" />\n<link rel="icon" type="image/png" sizes="16x16" href="/icons/favicon-16x16.png" />\n<style>th.eur,td.eur{display: table-cell;} tr.teur { display: table-row; } .dol,.tdol{ display: none; } .data-dol .eur, .data-dol .teur { display: none; } .data-dol tr.tdol { display: table-row; } .data-dol th.dol,.data-dol td.dol { display: table-cell; } .data-dol span.dol{ display: inline; }</style>\n<title>Paro por municipios: Donostia/San Sebasti\xc3\xa1n - (Gipuzkoa) 2025 | Datosmacro.com</title><script src="https://e00-ue.uecdn.es/cookies/js/policy_v4.js"></script><script>\nwindow.gdprAppliesGlobally=true;(function(){function a(e){if(!window.frames[e]){if(document.body&&document.body.firstChild){var t=document.body;var n=document.createElement("iframe");n.style.display="none";n.name=e;n.title=e;t.insertBefore(n,t.firstChild)}\nelse{setTimeout(function(){a(e)},5)}}}function e(n,r,o,c,s){function e(e,t,n,a){if(typeof n!=="function"){return}if(!window[r]){window[r]=[]}var i=false;if(s){i=s(e,t,n)}if(!i){window[r].push( ...

# %% [markdown]
# Toca inspeccionar la web para ver cómo obtener la tabla que nos interesa.

# %%
# !pip install beautifulsoup4 lxml

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(page.content, "html.parser")

# %%
from io import StringIO

results = soup.find(id="tb1")
data_scrap = pd.read_html(StringIO(str(results)))[0]

# %%
data_scrap
# Out:
#              Fecha Tasa de Paro Registrado  Tasa de Paro Registrado.1  \
# 0   Diciembre 2024                   6,91%                        NaN
# 1             2023                   7,09%                        NaN
# 2             2022                   7,58%                        NaN
# 3             2021                   8,08%                        NaN
# 4             2020                   9,25%                        NaN
# 5             2019                   7,66%                        NaN
# 6             2018                   8,21%                        NaN
# 7             2017                   8,99%                        NaN
# 8             2016                   9,53%                        NaN
# 9             2015                  10,59%                        NaN
# 10            2014                  11,89%                        NaN
# 11            2013                  12,47%                        NaN
# 12            2012                  12,53%                        NaN
# 13            2011                  10,80%                        NaN
# 14            2010                  10,43%                        NaN
# 15            2009                   9,86%                        NaN
# 16            2008                   7,98%                        NaN
# 17            2007                   7,04%                        NaN
# 18            2006                   6,80%                        NaN
#
#     Nº de parados registrados  Población
# 0                       6.479    188.487
# 1                       6.626    188.136
# 2                       6.984    187.368
# 3                       7.367    187.892
# 4                       8.679    188.240
# 5                       7.246    187.415
# 6                       7.678    186.665
# 7                       8.323    186.370
# 8                       8.733    186.064
# 9                       9.668    186.095
# 10                     10.785    186.126
# 11                     11.193    186.500
# 12                     11.283    186.409
# 13                      9.806    186.185
# 14                      9.457    185.506
# 15                      8.954    185.357
# 16                      7.218    184.248
# 17                      5.884    183.090
# 18                      6.005    183.308

# %%
data_scrap.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 5 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Fecha                      19 non-null     object
#  1   Tasa de Paro Registrado    19 non-null     object
#  2   Tasa de Paro Registrado.1  0 non-null      float64
#  3   Nº de parados registrados  19 non-null     float64
#  4   Población                  19 non-null     float64
# dtypes: float64(3), object(2)
# memory usage: 892.0+ bytes

# %%
data_scrap.iloc[0,0] = '2024'
data_scrap["Urtea"] = data_scrap.Fecha.astype(int)
data_scrap["Langabezia Tasa"] = 2*(data_scrap["Nº de parados registrados"]/data_scrap["Población"])*100
data_scrap
# Out:
#    Fecha Tasa de Paro Registrado  Tasa de Paro Registrado.1  \
# 0   2024                   6,91%                        NaN
# 1   2023                   7,09%                        NaN
# 2   2022                   7,58%                        NaN
# 3   2021                   8,08%                        NaN
# 4   2020                   9,25%                        NaN
# 5   2019                   7,66%                        NaN
# 6   2018                   8,21%                        NaN
# 7   2017                   8,99%                        NaN
# 8   2016                   9,53%                        NaN
# 9   2015                  10,59%                        NaN
# 10  2014                  11,89%                        NaN
# 11  2013                  12,47%                        NaN
# 12  2012                  12,53%                        NaN
# 13  2011                  10,80%                        NaN
# 14  2010                  10,43%                        NaN
# 15  2009                   9,86%                        NaN
# 16  2008                   7,98%                        NaN
# 17  2007                   7,04%                        NaN
# 18  2006                   6,80%                        NaN
#
#     Nº de parados registrados  Población  Urtea  Langabezia Tasa
# 0                       6.479    188.487   2024         6.874745
# 1                       6.626    188.136   2023         7.043841
# 2                       6.984    187.368   2022         7.454848
# 3                       7.367    187.892   2021         7.841739
# 4                       8.679    188.240   2020         9.221207
# 5                       7.246    187.415   2019         7.732572
# 6                       7.678    186.665   2018         8.226502
# 7                       8.323    186.370   2017         8.931695
# 8                       8.733    186.064   2016         9.387093
# 9                       9.668    186.095   2015        10.390392
# 10                     10.785    186.126   2014        11.588924
# 11                     11.193    186.500   2013        12.003217
# 12                     11.283    186.409   2012        12.105639
# 13                      9.806    186.185   2011        10.533609
# 14                      9.457    185.506   2010        10.195897
# 15                      8.954    185.357   2009         9.661356
# 16                      7.218    184.248   2008         7.835092
# 17                      5.884    183.090   2007         6.427440
# 18                      6.005    183.308   2006         6.551814

# %%
data_futura = data_scrap[data_scrap["Urtea"].isin([2024,2023,2022])]
data_futura
# Out:
#   Fecha Tasa de Paro Registrado  Tasa de Paro Registrado.1  \
# 0  2024                   6,91%                        NaN
# 1  2023                   7,09%                        NaN
# 2  2022                   7,58%                        NaN
#
#    Nº de parados registrados  Población  Urtea  Langabezia Tasa
# 0                      6.479    188.487   2024         6.874745
# 1                      6.626    188.136   2023         7.043841
# 2                      6.984    187.368   2022         7.454848

# %%
datos_completos = pd.concat([ciudad[["Urtea","Langabezia Tasa"]], datos_promedio[["Urtea","Langabezia Tasa"]], data_futura[["Urtea","Langabezia Tasa"]]])
datos_completos
# Out:
#     Urtea  Langabezia Tasa
# 0    2016        12.000000
# 1    2017         9.500000
# 2    2018         8.500000
# 3    2019         8.010000
# 4    2020         9.470000
# 0    1997        12.069271
# 1    1998        10.730279
# 2    1999         9.158212
# 3    2000         8.045970
# 4    2001         7.367619
# 5    2001         7.257565
# 6    2003         6.612094
# 7    2004         6.152541
# 8    2005         6.718122
# 9    2005         6.895029
# 10   2007         6.741183
# 11   2008         7.540679
# 0    2024         6.874745
# 1    2023         7.043841
# 2    2022         7.454848

# %%
datos_completos = datos_completos.groupby("Urtea").agg("mean")
datos_completos.reset_index(inplace=True)

# %%
plot_unemployment_rates(datos_completos);

# %% [markdown]
# Exportamos el contenido para poder usarlo en otras herramientas.

# %%
datos_completos.to_csv("../data/datos_completos.csv", index=False)
